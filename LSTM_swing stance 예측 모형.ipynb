# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from keras.layers import *
from keras.models import *
from keras.utils import *
from sklearn.preprocessing import *

# %%
feat = ['feat_{}'.format(i) for i in range(12)]

df = pd.read_csv('./dataset/jung_pha1.csv', names=feat)

df
# Out:
#     feat_0 feat_1               feat_2            feat_3             feat_4  \
# 0     tick  phase  nose_shoulder_angle  left_elbow_angle  right_elbow_angle
# 1        1      0          60.72588998       177.3460742        176.7026647
# 2        2      0          60.50485551        178.510853         177.074815
# 3        3      0          58.33250319       179.0006267        176.0538324
# 4        4      0          58.27248891       179.2873072        176.0943607
# ..     ...    ...                  ...               ...                ...
# 310    310      1          55.45297544       171.0598767        137.6081338
# 311    311      1           55.0423374       171.8460171        155.9028413
# 312    312      1          54.77316128       172.1445395        161.8132375
# 313    313      1          55.48523589       172.1550318        168.8844083
# 314    314      1          55.72462568       171.5971573        150.8217889
#
#                feat_5           feat_6          feat_7             feat_8  \
# 0    right_knee_angle  left_knee_angle  shoulder_angle  right_ankle_angle
# 1         176.8088442      175.9024915      172.360475        172.8671503
# 2         177.7654036       178.774223     172.8063187        174.2661776
# 3         177.3685957      179.6361985     174.5298348        171.7758925
# 4         177.1870217      179.2263156     174.9476908        171.6851582
# ..                ...              ...             ...                ...
# 310       167.5847927      178.5469219     177.0007905        130.6141249
# 311        168.379407      178.1687757     178.3289822        126.0311248
# 312       170.6407373       178.951887     179.1695716        120.8513845
# 313       172.2662406      179.2520639     179.7245001        120.4646967
# 314        169.297908      177.0286788     179.0266148        91.93116728
#
#               feat_9           feat_10         feat_11
# 0    right_hip_angle  left_ankle_angle  left_hip_angle
# 1        0.610396897       156.8124633     2.142409084
# 2        0.250456155       158.6677406     3.494882141
# 3        0.107370191       154.7168454     4.571375872
# 4        0.280711388        154.141191     4.423470473
# ..               ...               ...             ...
# 310      1.877353051       113.1960826     5.098941173
# 311      2.104899919        107.044547     4.945592161
# 312      0.973246182       99.51642992     5.255277214
# 313      0.956397423       105.0261303     4.178911982
# 314      0.839865308       103.1112453     3.689537769
#
# [315 rows x 12 columns]

# %%
df.dtypes
# Out:
# feat_0     object
# feat_1     object
# feat_2     object
# feat_3     object
# feat_4     object
# feat_5     object
# feat_6     object
# feat_7     object
# feat_8     object
# feat_9     object
# feat_10    object
# feat_11    object
# dtype: object

# %%
df1 = df

# %%
df1 = df.apply(pd.to_numeric, errors='coerce')

# %%
df1.dropna(inplace=True)
df1
# Out:
#      feat_0  feat_1     feat_2      feat_3      feat_4      feat_5  \
# 1       1.0     0.0  60.725890  177.346074  176.702665  176.808844
# 2       2.0     0.0  60.504856  178.510853  177.074815  177.765404
# 3       3.0     0.0  58.332503  179.000627  176.053832  177.368596
# 4       4.0     0.0  58.272489  179.287307  176.094361  177.187022
# 5       5.0     0.0  58.660763  178.947536  176.156688  177.563194
# ..      ...     ...        ...         ...         ...         ...
# 310   310.0     1.0  55.452975  171.059877  137.608134  167.584793
# 311   311.0     1.0  55.042337  171.846017  155.902841  168.379407
# 312   312.0     1.0  54.773161  172.144540  161.813238  170.640737
# 313   313.0     1.0  55.485236  172.155032  168.884408  172.266241
# 314   314.0     1.0  55.724626  171.597157  150.821789  169.297908
#
#          feat_6      feat_7      feat_8    feat_9     feat_10   feat_11
# 1    175.902491  172.360475  172.867150  0.610397  156.812463  2.142409
# 2    178.774223  172.806319  174.266178  0.250456  158.667741  3.494882
# 3    179.636199  174.529835  171.775892  0.107370  154.716845  4.571376
# 4    179.226316  174.947691  171.685158  0.280711  154.141191  4.423470
# 5    178.508390  174.940494  171.680656  0.183633  151.785437  4.588570
# ..          ...         ...         ...       ...         ...       ...
# 310  178.546922  177.000790  130.614125  1.877353  113.196083  5.098941
# 311  178.168776  178.328982  126.031125  2.104900  107.044547  4.945592
# 312  178.951887  179.169572  120.851384  0.973246   99.516430  5.255277
# 313  179.252064  179.724500  120.464697  0.956397  105.026130  4.178912
# 314  177.028679  179.026615   91.931167  0.839865  103.111245  3.689538
#
# [314 rows x 12 columns]

# %%
Y = df1['feat_1']
Y = to_categorical(Y)

df1.drop(['feat_1'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'feat_1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17260/651283470.py in <module>
# ----> 1 Y = df1['feat_1']
#       2 Y = to_categorical(Y)
#       3
#       4 df1.drop(['feat_1'], axis=1, inplace=True)
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'feat_1'

# %%
X_train = np.asarray(df1[:-100].values.tolist(), dtype=np.float64)
X_test = np.asarray(df1[-100:].values.tolist(), dtype=np.float64)

# %%
Y_train = Y[:-100]
Y_test = Y[-100:]

X_train = X_train[:200]
Y_train = Y_train[:200]

# %%
X_train = X_train.reshape(-1, 20, 11)
Y_train = Y_train.reshape(-1, 20, 2)
X_test = X_test.reshape(-1, 10, 11)
Y_test = Y_test.reshape(-1, 10, 2)

# %%
print(X_train.shape)
# Out:
# (10, 20, 11)

# %%
print(X_test.shape)
# Out:
# (10, 10, 11)

# %%
#X_train = X_train.reshape(214, 11)
##Y_train = Y_train.reshape(214, 2)
#X_test = X_test.reshape(100, 11)
#Y_test = Y_test.reshape(100, 2)

# %%
#X_train = X_train.reshape(214, 11, -1)
#Y_train = Y_train.reshape(214, 2, -1)
#X_test = X_test.reshape(100, 11, -1)
#Y_test = Y_test.reshape(100, 2, -1)

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(20, 11, ), return_sequences=True))
model.add(LSTM(256, return_sequences=True))
model.add(Dense(2, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_69 (LSTM)              (None, 20, 128)           71680
#
#  lstm_70 (LSTM)              (None, 20, 256)           394240
#
#  dense_33 (Dense)            (None, 20, 2)             514
#
# =================================================================
# Total params: 466,434
# Trainable params: 466,434
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (10, 20, 11)
# (10, 20, 2)

# %%
hist = model.fit(X_train, Y_train, epochs=10, batch_size=1, validation_split=0.2)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 2s 88ms/step - loss: 0.7130 - accuracy: 0.7063 - val_loss: 0.6512 - val_accuracy: 0.7250
# Epoch 2/10
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5914 - accuracy: 0.7312 - val_loss: 0.6359 - val_accuracy: 0.7000
# Epoch 3/10
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4893 - accuracy: 0.7312 - val_loss: 0.7148 - val_accuracy: 0.5250
# Epoch 4/10
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4739 - accuracy: 0.8125 - val_loss: 0.6670 - val_accuracy: 0.6250
# Epoch 5/10
# 8/8 [==============================] - 0s 20ms/step - loss: 0.3879 - accuracy: 0.8500 - val_loss: 0.8505 - val_accuracy: 0.3500
# Epoch 6/10
# 8/8 [==============================] - 0s 22ms/step - loss: 0.3721 - accuracy: 0.8313 - val_loss: 0.8515 - val_accuracy: 0.5750
# Epoch 7/10
# 8/8 [==============================] - 0s 20ms/step - loss: 0.3256 - accuracy: 0.8687 - val_loss: 0.9403 - val_accuracy: 0.4000
# Epoch 8/10
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2961 - accuracy: 0.8687 - val_loss: 0.7118 - val_accuracy: 0.5000
# Epoch 9/10
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2672 - accuracy: 0.8875 - val_loss: 0.5044 - val_accuracy: 0.7750
# Epoch 10/10
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4616 - accuracy: 0.8375 - val_loss: 0.6347 - val_accuracy: 0.6000

# %%
# timelag 짜는 법  타임래그가 있어야 돌아감
